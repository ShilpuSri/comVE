# %%
# !git clone https://github.com/nshepperd/gpt-2
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 431 (delta 17), reused 43 (delta 8), pack-reused 371
# Receiving objects: 100% (431/431), 4.48 MiB | 19.59 MiB/s, done.
# Resolving deltas: 100% (218/218), done.

# %%
# !python ./gpt-2/download_model.py 124M
# Out:
# Fetching checkpoint: 1.00kit [00:00, 1.01Mit/s]
# Fetching encoder.json: 1.04Mit [00:00, 3.80Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 679kit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:25, 19.9Mit/s]
# Fetching model.ckpt.index: 6.00kit [00:00, 5.81Mit/s]
# Fetching model.ckpt.meta: 472kit [00:00, 2.21Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 2.13Mit/s]

# %%
# !cp ./gpt-2/train.py ./gpt-2/src/

# %%
# !python ./gpt-2/src/train.py --dataset ../input/testdata/file2_124.npz --sample_every 1000 --sample_num 3
# Out:
# 2021-03-16 22:01:16.643916: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.2
# 2021-03-16 22:01:16.755090: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.2
# 2021-03-16 22:01:21.105209: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-16 22:01:21.108446: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-16 22:01:21.475780: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-16 22:01:21.476939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# ...

# %%
# !python ./gpt-2/src/train.py --restore_from ./checkpoint/run1/ --dataset ../input/testdata/file2_124.npz --sample_every 1000 --sample_num 3
# Out:
# 2021-03-17 00:06:38.573917: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.2
# 2021-03-17 00:06:38.576325: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.2
# 2021-03-17 00:06:40.490489: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-17 00:06:40.491562: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-17 00:06:40.803172: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-17 00:06:40.803882: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# ...

# %%
# !mkdir ./mymodel1

# %%
# !cp ./checkpoint/run1/* ./mymodel1

# %%
# !ls -lrt ./mymodel1
# Out:
# total 5042384
# -rw-r--r-- 1 root root         6 Mar 17 00:31 counter
# -rw-r--r-- 1 root root       246 Mar 17 00:31 checkpoint
# -rw-r--r-- 1 root root    332715 Mar 17 00:31 events.out.tfevents.1615939613.907eaf4fa473
# -rw-r--r-- 1 root root    519071 Mar 17 00:31 events.out.tfevents.1615932096.907eaf4fa473
# -rw-r--r-- 1 root root      5215 Mar 17 00:31 model-10000.index
# -rw-r--r-- 1 root root 497759232 Mar 17 00:31 model-10000.data-00000-of-00001
# -rw-r--r-- 1 root root   3090817 Mar 17 00:31 model-10000.meta
# -rw-r--r-- 1 root root      5215 Mar 17 00:31 model-11000.index
# -rw-r--r-- 1 root root 497759232 Mar 17 00:31 model-11000.data-00000-of-00001
# -rw-r--r-- 1 root root   3090817 Mar 17 00:31 model-11000.meta
# -rw-r--r-- 1 root root      5215 Mar 17 00:31 model-12000.index
# -rw-r--r-- 1 root root 497759232 Mar 17 00:31 model-12000.data-00000-of-00001
# -rw-r--r-- 1 root root   3090817 Mar 17 00:31 model-12000.meta
# ...

# %%
# !mkdir ./model_run1

# %%
# !cp ./mymodel1/checkpoint ./model_run1

# %%
# !cp ./mymodel1/model-13000.index ./model_run1

# %%
# !cp ./mymodel1/model-13000.data-00000-of-00001 ./model_run1

# %%
# !cp ./mymodel1/model-13000.meta ./model_run1

# %%
# !cp ./models/124M/encoder.json ./model_run1

# %%
# !cp ./models/124M/hparams.json ./model_run1

# %%
# !cp ./models/124M/vocab.bpe ./model_run1

# %%
# !pip install fire
# Out:
# ...
#      |████████████████████████████████| 87 kB 2.8 MB/s eta 0:00:011
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=ad09e0baad4b8553729d2ee4f0eb3c07becf2c288e93f01c5c875e15cea2bd58
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...

# %%
# !cp ../input/input2/interactive_conditional_samples1.py ./gpt-2/src/

# %%
# !python ./gpt-2/src/interactive_conditional_samples1.py --temperature 0.8 --top_k 40 --length 30 --model_name ./model_run1 --models_dir .
# Out:
# 2021-03-17 00:35:53.414793: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.2
# 2021-03-17 00:35:53.417322: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.2
# 2021-03-17 00:35:56.057891: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-17 00:35:56.071187: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-17 00:35:56.389900: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-17 00:35:56.390935: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# ...
